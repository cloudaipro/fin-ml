# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import pandas_datareader.data as web
from matplotlib import pyplot
import seaborn as sns

# hyperparameters turning
from ray import tune, train, ray
from ray.tune.schedulers import ASHAScheduler
ray.init(log_to_driver=False)

#Plotting 
from pandas.plotting import scatter_matrix

#Libraries for Statistical Models
import statsmodels.api as sm

#Diable the warnings
import warnings
warnings.filterwarnings('ignore')

_TARGET_STK = 'MSFT'
pd.options.display.max_columns = None
pd.options.display.expand_frame_repr = False
# Out:
# 2024-01-19 20:04:32,970	INFO worker.py:1724 -- Started a local Ray instance.

# %%
from datetime import datetime
import yfinance as yfin

# Loading the data
stk_tickers = [_TARGET_STK, 'IBM', 'GOOGL']
ccy_tickers = ['DEXJPUS', 'DEXUSUK']
idx_tickers = ['VIXCLS', 'SP500', 'DJIA']

start = datetime(2014, 1, 1)
end = datetime(2023, 12, 31)
# stk_data = web.get_data_yahoo(stk_tickers, start, end)
stk_data = yfin.download(stk_tickers, start, end).dropna()
ccy_data = web.DataReader(ccy_tickers, 'fred', start, end).dropna()
idx_data = web.DataReader(idx_tickers, 'fred', start, end).dropna()

print(stk_data)
print(ccy_data)
print(idx_data)
# Out:
# [*********************100%%**********************]  3 of 3 completed
#              Adj Close                               Close                                High                                 Low                                Open                             Volume
#                  GOOGL         IBM        MSFT       GOOGL         IBM        MSFT       GOOGL         IBM        MSFT       GOOGL         IBM        MSFT       GOOGL         IBM        MSFT      GOOGL      IBM      MSFT
# Date
# 2014-01-02   27.855856  116.571358   31.290817   27.855856  177.370941   37.160000   27.971722  179.158707   37.400002   27.734234  177.055450   37.099998   27.914413  178.977051   37.349998   72783144  4755639  30632200
# 2014-01-03   27.652653  117.268768   31.080303   27.652653  178.432129   36.910000   27.951200  179.110901   37.220001   27.650902  177.151047   36.599998   27.902903  177.657745   37.200001   66601332  4250107  31134800
# 2014-01-06   27.960960  116.866623   30.423504   27.960960  177.820267   36.130001   27.999498  179.120453   36.889999   27.688688  177.151047   36.110001   27.853104  178.919693   36.849998   70701228  4254919  43603700
# 2014-01-07   28.500000  119.197685   30.659273   28.500000  181.367111   36.410000   28.520771  181.978973   36.490002   28.057056  178.183563   36.209999   28.153152  178.193115   36.330002  102001896  6205186  35802800
# 2014-01-08   28.559309  118.104431   30.111944   28.559309  179.703629   35.759998   28.711712  181.089859   36.139999   28.360611  179.024857   35.580002   28.678679  181.003830   36.000000   89610300  4815470  59971700
# ...                ...         ...         ...         ...         ...         ...         ...         ...         ...         ...         ...         ...         ...         ...         ...        ...      ...       ...
# 2023-12-22  141.490005  162.139999  374.579987  141.490005  162.139999  374.579987  141.990005  162.410004  375.179993  140.710007  161.000000  372.709991  140.770004  161.100006  373.679993   26514600  2439800  17091100
# 2023-12-26  141.520004  163.210007  374.660004  141.520004  163.210007  374.660004  142.679993  163.309998  376.940002  141.190002  162.050003  373.500000  141.589996  162.229996  375.000000   16780300  1772400  12673100
# 2023-12-27  140.369995  163.460007  374.070007  140.369995  163.460007  374.070007  142.080002  163.639999  375.059998  139.889999  162.679993  372.809998  141.589996  163.139999  373.690002   19628600  3234600  14905400
# 2023-12-28  140.229996  163.750000  375.279999  140.229996  163.750000  375.279999  141.139999  163.960007  376.459991  139.750000  163.399994  374.160004  140.779999  163.960007  375.369995   16045700  2071300  14327000
# 2023-12-29  139.690002  163.550003  376.040009  139.690002  163.550003  376.040009  140.360001  164.179993  377.160004  138.779999  162.830002  373.480011  139.630005  163.750000  376.000000   18727200  2525600  18723000
#
# [2516 rows x 18 columns]
#             DEXJPUS  DEXUSUK
# DATE
# 2014-01-02   104.84   1.6441
# 2014-01-03   104.46   1.6424
# 2014-01-06   104.38   1.6412
# 2014-01-07   104.54   1.6421
# 2014-01-08   104.87   1.6461
# ...             ...      ...
# 2023-12-22   142.60   1.2720
# 2023-12-26   142.48   1.2709
# 2023-12-27   142.05   1.2797
# 2023-12-28   141.08   1.2743
# 2023-12-29   140.92   1.2743
#
# [2497 rows x 2 columns]
#             VIXCLS    SP500      DJIA
# DATE
# 2014-01-21   12.87  1843.80  16414.44
# 2014-01-22   12.84  1844.86  16373.34
# 2014-01-23   13.77  1828.46  16197.35
# 2014-01-24   18.14  1790.29  15879.11
# 2014-01-27   17.42  1781.56  15837.88
# ...            ...      ...       ...
# 2023-12-22   13.03  4754.63  37385.97
# 2023-12-26   12.99  4774.75  37545.33
# 2023-12-27   12.43  4781.58  37656.52
# 2023-12-28   12.47  4783.35  37710.10
# 2023-12-29   12.45  4769.83  37689.54
#
# [2504 rows x 3 columns]

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
validation_size = 0.2
epoch_num = 300
batch_size = 32
log_dir = f'/mnt/AIWorkSpace/work/fin-ml/runs/{_TARGET_STK}'

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
class LSTMDataSet(Dataset):
    def __init__(self, X, Y, seq_len, features):
        self.X = X
        self.Y = Y
        self.seq_len = seq_len
        self.features = features
    def __len__(self):
        return len(self.X) - self.seq_len + 1
    
    def __getitem__(self, idx):
        return (torch.tensor(np.array(self.X[idx: idx + self.seq_len].loc[:, self.features]), dtype=torch.float32),
                torch.tensor(np.array(self.Y.iloc[idx + self.seq_len - 1,:]), dtype=torch.float32))

# %%
from torch import nn
class StockPricePredictionLSTM(nn.Module):
    def __init__(self, seq_len, input_size, hidden_size, num_layers, num_fc_layers, activation_type):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        """
            input_size    : The number of expected features in the input x
            hidden_size   : The number of features in the hidden state h
            num_layers    : Number of recurrent layers. E.g., setting num_layers=2 would mean stacking two LSTMs together to form a stacked LSTM, with the second LSTM taking in outputs of the first LSTM and computing the final results. Default: 1
            bias          : If False, then the layer does not use bias weights b_ih and b_hh. Default: True
            batch_first   : If True, then the input and output tensors are provided as (batch, seq, feature) instead of (seq, batch, feature). Note that this does not apply to hidden or cell states. See the Inputs/Outputs sections below for details. Default: False
            dropout       : If non-zero, introduces a Dropout layer on the outputs of each LSTM layer except the last layer, with dropout probability equal to dropout. Default: 0
            bidirectional : If True, becomes a bidirectional LSTM. Default: False
            proj_size     : If > 0, will use LSTM with projections of corresponding size. Default: 0
        """
        self.rnn = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)

        layers = []
        in_features = self.hidden_size
        for i in range(1, num_fc_layers):
            out_features = int(in_features / 2)
            if (out_features <= 1):
                break
            layers.append(nn.Linear(in_features, out_features))
            layers.append(nn.ReLU() if activation_type == 1 else
                          nn.Sigmoid()) if activation_type == 2 else nn.Tanh()
            in_features = out_features

        layers.append(nn.Linear(in_features, 1))
        self.fc = nn.Sequential(*layers)
        self.fc.apply(self.init_weights)

    def init_weights(self, m):
        if isinstance(m, nn.Linear):
            initrange = 0.5
            nn.init.uniform_(m.weight, -initrange, initrange)
            nn.init.zeros_(m.bias)
            # print(f"{m.in_features},{m.out_features}")

    def forward(self, x):
        h_0 = torch.zeros(self.num_layers, x.shape[0], self.hidden_size).to(device)
        c_0 = torch.zeros(self.num_layers, x.shape[0], self.hidden_size).to(device)
        out, (h_out, _) = self.rnn(x, (h_0, c_0))

        fc_input = h_out[-1].view(-1, self.hidden_size)
        return self.fc(fc_input)

# %%
import math 
from sklearn.metrics import mean_squared_error

def eval_dl_method(model, dl, criterion=None, device=device):
    model.eval()
    y_gt = []
    y_pred = []
    vloss = 0.0
    for i, (x, y) in enumerate(dl):
        x = x.to(device)
        y = y.to(device)
        outputs = model(x)
        if criterion != None:
            vloss += criterion(outputs, y).item()
        # print(f"{i}:{vloss}")
        y_gt.extend(y.cpu().detach().numpy().reshape(-1))
        y_pred.extend(outputs.cpu().detach().numpy().reshape(-1))
    
    return (math.sqrt(mean_squared_error(y_gt, y_pred)), y_gt, y_pred, vloss)

# %%
from sklearn.preprocessing import StandardScaler, Normalizer
from sklearn_pandas import DataFrameMapper


def gen_analysis_data(stock_name, return_period):
    import pandas_ta
    data = stk_data.xs(stock_name, axis=1, level=1)
    
    data = pd.concat([data.ta.percent_return(length=return_period, prefix=stock_name),
                      data.ta.adosc(prefix=stock_name),
                      data.ta.kvo(prefix=stock_name)], 
                      axis=1)
    data = data.dropna().astype('float32')
    return data

def prepare_dataloader(return_period, seq_len):
    Target_Data = gen_analysis_data(_TARGET_STK, return_period)
    GOOGL_Data = gen_analysis_data('GOOGL', return_period)
    IBM_Data = gen_analysis_data('IBM', return_period)

    X1 = pd.concat([Target_Data, GOOGL_Data, IBM_Data], axis=1)

    X2 = ccy_data.pct_change(return_period).dropna()
    X2 = X2.rename(columns={ column : f"{column}_PCTRET_{return_period}" for column in X2.columns.to_list()})

    X3 = pd.concat([idx_data['SP500'].pct_change(return_period), idx_data['DJIA'].pct_change(return_period)], axis=1)
    X3 = X3.rename(columns={ column : f"{column}_PCTRET_{return_period}" for column in X3.columns.to_list()})
    X3 = pd.concat([idx_data['VIXCLS'], X3], axis=1).dropna()

    X1_X2_X3 = pd.concat([X1, X2, X3], axis=1).dropna()
    features = X1_X2_X3.columns.to_list()

    Y_raw = stk_data.loc[:, ('Adj Close', _TARGET_STK)].to_frame().pct_change(return_period).shift(-return_period).dropna().astype('float32')
    Y_raw.columns = [f"{_TARGET_STK}_pred_{return_period}"]

    dataset = pd.concat([Y_raw, X1_X2_X3], axis=1).dropna()

    X = dataset.loc[:, X1_X2_X3.columns]
    Y = dataset.loc[:, Y_raw.columns]

    train_size = int(len(X) * (1 - validation_size))
    X_train = X.iloc[0:train_size].loc[:,features]
    Y_train = Y.iloc[0:train_size]
    X_test  = X.iloc[train_size - seq_len + 1:len(X)].loc[:, features]
    Y_test  = Y.iloc[train_size - seq_len + 1:len(Y)]

    X_dfm = DataFrameMapper(
        [ ([column], StandardScaler()) for column in X_train.columns.to_list()]
        , input_df=True, df_out=True)
    X_train = X_dfm.fit_transform(X_train)
    X_test = X_dfm.transform(X_test)

    train_loader = DataLoader(LSTMDataSet(X_train, Y_train, seq_len, features), batch_size=batch_size)
    test_loader = DataLoader(LSTMDataSet(X_test, Y_test, seq_len,features), batch_size=batch_size)

    return train_loader, test_loader, features

# %%
from tqdm import tqdm
from torch.utils.tensorboard import SummaryWriter

import warnings
warnings.filterwarnings('ignore')

def do_train(model, optimizer, train_dl, test_dl, id_str, writer):
    criterion = torch.nn.MSELoss()

    model_name = f"{log_dir}/{id_str}.pt"
    best_loss = 999999999    
    total_loss = 0.0
    total_vloss = 0.0
    for epoch in tqdm(range(epoch_num)):
        model.train()
        running_loss = 0.0
        
        for i, (x, y) in enumerate(train_dl):
            x = x.to(device)
            y = y.to(device)
            optimizer.zero_grad()
            outputs = model(x)
            loss = criterion(outputs, y)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            
            if loss.item() < best_loss:
                best_loss = loss.item()
                torch.save(model.state_dict(), model_name)

        with torch.no_grad():
            (testScore, test_y_gt, test_y_pred, running_vloss)  = eval_dl_method(model, test_dl, criterion)
            train.report({"mse_score":testScore})
            
        writer.add_scalars('Training vs. Validation Loss',
                            { 'Training' : running_loss / len(train_dl), 'Validation' : running_vloss / len(test_dl) },
                            epoch + 1)
        total_loss += running_loss / len(train_dl)
        total_vloss += running_vloss / len(test_dl)

        writer.flush()
        
    return {'Train loss':total_loss/epoch_num, 'Validation loss': total_vloss/epoch_num}

def train_LSTM(config):
    return_period = config["return_period"]
    seq_len = config["seq_len"]
    lr = config["lr"]
    momentum = config["momentum"]
    optim_type = config["optim_type"]
    num_layers = config["num_layers"]
    hidden_size = config["hidden_size"]
    num_fc_layers = config["num_fc_layers"]
    activation_type = config["activation_type"]

    id_str = f"{return_period}_{seq_len}_{lr}_{momentum}_{optim_type}_{num_layers}_{hidden_size}_{num_fc_layers}_{activation_type}"

    writer = SummaryWriter(f"{log_dir}/{id_str}")    

    train_loader, test_loader, features = prepare_dataloader(return_period, seq_len)
    model = StockPricePredictionLSTM(seq_len, input_size=len(features),
                                     hidden_size=hidden_size,num_layers=num_layers,
                                     num_fc_layers=num_fc_layers, activation_type=activation_type)
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr) if optim_type == 1 else torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum)
    metric_dict = do_train(model, optimizer, train_loader, test_loader, id_str, writer)
    writer.add_hparams(
        {
            "return_period": return_period,
            "seq_len": seq_len,
            "lr": lr,
            "momentum": momentum,
            "optim_type": optim_type,
            "num_layers": num_layers,
            "hidden_size": hidden_size,
            "num_fc_layers": num_fc_layers,
            "activation_type": activation_type
        },
        metric_dict
    )
    writer.close()
# Out:
# 2024-01-18 16:40:40.089167: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-18 16:40:40.109561: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-18 16:40:40.297014: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-18 16:40:40.775800: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import warnings
warnings.filterwarnings('ignore', category=Warning)
warnings.filterwarnings('ignore', module='TF-TRT')
warnings.filterwarnings('ignore', module='tensorflow')
warnings.filterwarnings('ignore', category=RuntimeWarning)
warnings.filterwarnings('ignore', category=UserWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=SyntaxWarning)
warnings.filterwarnings('ignore', category=PendingDeprecationWarning)
warnings.filterwarnings('ignore', category=ImportWarning)
warnings.filterwarnings('ignore', category=UnicodeWarning)
warnings.filterwarnings('ignore', category=BytesWarning)
warnings.filterwarnings('ignore', category=ResourceWarning)
warnings.simplefilter("always")


search_space = {
    "return_period": tune.grid_search([2,3,5,10]),
    "seq_len": tune.grid_search([2,3,4,5]),
    "lr": tune.grid_search([0.001, 0.01, 0.1]),
    "momentum": tune.uniform(0.1, 0.9),
    "optim_type": tune.grid_search([1, 2]),
    "num_layers": tune.grid_search([1, 2, 4, 8]),
    "hidden_size": tune.grid_search([8, 16, 32, 64, 128]),
    "num_fc_layers": tune.grid_search([1, 2, 3]),
    "activation_type": tune.grid_search([1, 2, 3])
}

time_str = datetime.now().strftime('%Y-%m-%d_%H.%M.%S')
log_dir = f'/mnt/AIWorkSpace/work/fin-ml/runs/{_TARGET_STK}/{time_str}'

analysis = tune.run(train_LSTM, 
                    config=search_space,
                    resources_per_trial={'cpu':0.125, 'gpu':0.125},
                    metric="mse_score",
                    mode="min")
# Out:
# 2024-01-18 16:45:12,671	INFO tune.py:583 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# 2024-01-18 16:45:12,682	WARNING callback.py:137 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-01-19 15:14:53</td></tr>
# <tr><td>Running for: </td><td>22:29:40.68        </td></tr>
# <tr><td>Memory:      </td><td>22.7/31.1 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/32 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#
#   Number of errored trials: 29<br><table>
# <thead>
# <tr><th>Trial name            </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                                                                                              </th></tr>
# </thead>
# <tbody>
# <tr><td>train_LSTM_011e8_00627</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_00627_627_activation_type=1,hidden_size=128,lr=0.1000,momentum=0.4100,num_fc_layers=2,num_layers=1,optim_type=2,r_2024-01-18_22-30-45/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_00629</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_00629_629_activation_type=3,hidden_size=128,lr=0.1000,momentum=0.2332,num_fc_layers=2,num_layers=1,optim_type=2,r_2024-01-18_22-31-00/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_00672</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_00672_672_activation_type=1,hidden_size=128,lr=0.1000,momentum=0.5215,num_fc_layers=3,num_layers=1,optim_type=2,r_2024-01-18_22-53-56/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_00674</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_00674_674_activation_type=3,hidden_size=128,lr=0.1000,momentum=0.5221,num_fc_layers=3,num_layers=1,optim_type=2,r_2024-01-18_22-54-18/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_00764</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_00764_764_activation_type=3,hidden_size=128,lr=0.1000,momentum=0.6897,num_fc_layers=2,num_layers=2,optim_type=2,r_2024-01-18_23-44-50/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_00807</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_00807_807_activation_type=1,hidden_size=128,lr=0.1000,momentum=0.1174,num_fc_layers=3,num_layers=2,optim_type=2,r_2024-01-19_00-08-01/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_00809</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_00809_809_activation_type=3,hidden_size=128,lr=0.1000,momentum=0.1574,num_fc_layers=3,num_layers=2,optim_type=2,r_2024-01-19_00-11-45/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_00899</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_00899_899_activation_type=3,hidden_size=128,lr=0.1000,momentum=0.2698,num_fc_layers=2,num_layers=4,optim_type=2,r_2024-01-19_01-02-48/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_00942</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_00942_942_activation_type=1,hidden_size=128,lr=0.1000,momentum=0.3005,num_fc_layers=3,num_layers=4,optim_type=2,r_2024-01-19_01-26-37/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_00944</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_00944_944_activation_type=3,hidden_size=128,lr=0.1000,momentum=0.4676,num_fc_layers=3,num_layers=4,optim_type=2,r_2024-01-19_01-27-12/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_01032</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_01032_1032_activation_type=1,hidden_size=128,lr=0.1000,momentum=0.8055,num_fc_layers=2,num_layers=8,optim_type=2,_2024-01-19_02-18-44/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_01077</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_01077_1077_activation_type=1,hidden_size=128,lr=0.1000,momentum=0.4480,num_fc_layers=3,num_layers=8,optim_type=2,_2024-01-19_02-43-34/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_01079</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_01079_1079_activation_type=3,hidden_size=128,lr=0.1000,momentum=0.4941,num_fc_layers=3,num_layers=8,optim_type=2,_2024-01-19_02-47-04/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_01707</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_01707_1707_activation_type=1,hidden_size=128,lr=0.1000,momentum=0.4962,num_fc_layers=2,num_layers=1,optim_type=2,_2024-01-19_08-57-08/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_01709</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_01709_1709_activation_type=3,hidden_size=128,lr=0.1000,momentum=0.7153,num_fc_layers=2,num_layers=1,optim_type=2,_2024-01-19_08-58-06/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_01739</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_01739_1739_activation_type=3,hidden_size=128,lr=0.0100,momentum=0.8672,num_fc_layers=3,num_layers=1,optim_type=2,_2024-01-19_09-15-41/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_01752</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_01752_1752_activation_type=1,hidden_size=128,lr=0.1000,momentum=0.2010,num_fc_layers=3,num_layers=1,optim_type=2,_2024-01-19_09-21-27/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_01754</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_01754_1754_activation_type=3,hidden_size=128,lr=0.1000,momentum=0.4070,num_fc_layers=3,num_layers=1,optim_type=2,_2024-01-19_09-24-29/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_01844</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_01844_1844_activation_type=3,hidden_size=128,lr=0.1000,momentum=0.4650,num_fc_layers=2,num_layers=2,optim_type=2,_2024-01-19_10-12-56/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_01887</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_01887_1887_activation_type=1,hidden_size=128,lr=0.1000,momentum=0.7571,num_fc_layers=3,num_layers=2,optim_type=2,_2024-01-19_10-39-14/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_01889</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_01889_1889_activation_type=3,hidden_size=128,lr=0.1000,momentum=0.6626,num_fc_layers=3,num_layers=2,optim_type=2,_2024-01-19_10-39-40/error.txt</td></tr>
# <tr><td>train_LSTM_011e8_01977</td><td style="text-align: right;">           1</td><td>/home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_01977_1977_activation_type=1,hidden_size=128,lr=0.1000,momentum=0.2329,num_fc_layers=2,num_layers=4,optim_type=2,_2024-01-19_11-30-50/error.txt</td></tr>
# <tr><td>train_LSTM_01
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name            </th><th>mse_score           </th></tr>
# </thead>
# <tbody>
# <tr><td>train_LSTM_011e8_00000</td><td>0.03482234358485952 </td></tr>
# <tr><td>train_LSTM_011e8_00001</td><td>0.03414521522565722 </td></tr>
# <tr><td>train_LSTM_011e8_00002</td><td>0.036823226666280934</td></tr>
# <tr><td>train_LSTM_011e8_00003</td><td>0.0384499942842203  </td></tr>
# <tr><td>train_LSTM_011e8_00004</td><td>0.0347754615224851  </td></tr>
# <tr><td>train_LSTM_011e8_00005</td><td>0.03780606490196064 </td></tr>
# <tr><td>train_LSTM_011e8_00006</td><td>0.0392132918247121  </td></tr>
# <tr><td>train_LSTM_011e8_00007</td><td>0.03885640972551623 </td></tr>
# <tr><td>train_LSTM_011e8_00008</td><td>0.03943063300204488 </td></tr>
# <tr><td>train_LSTM_011e8_00009</td><td>0.038881972510416425</td></tr>
# <tr><td>train_LSTM_011e8_00010</td><td>0.03848882318862577 </td></tr>
# <tr><td>train_LSTM_011e8_00011</td><td>0.039022724941743615</td></tr>
# <tr><td>train_LSTM_011e8_00012</td><td>0.037505175437029026</td></tr>
# <tr><td>train_LSTM_011e8_00013</td><td>0.03667437492081215 </td></tr>
# <tr><td>train_LSTM_011e8_00014</td><td>0.036478690796123266</td></tr>
# <tr><td>train_LSTM_011e8_00015</td><td>0.03779693374485325 </td></tr>
# <tr><td>train_LSTM_011e8_00016</td><td>0.04152995582333713 </td></tr>
# <tr><td>train_LSTM_011e8_00017</td><td>0.04115920961648499 </td></tr>
# <tr><td>train_LSTM_011e8_00018</td><td>0.04143479567715999 </td></tr>
# <tr><td>train_LSTM_011e8_00019</td><td>0.04863946947627061 </td></tr>
# <tr><td>train_LSTM_011e8_00020</td><td>0.03866981930759827 </td></tr>
# <tr><td>train_LSTM_011e8_00021</td><td>0.04207506844274671 </td></tr>
# <tr><td>train_LSTM_011e8_00022</td><td>0.036300166905622204</td></tr>
# <tr><td>train_LSTM_011e8_00023</td><td>0.04072565226660037 </td></tr>
# <tr><td>train_LSTM_011e8_00024</td><td>0.03328904087591465 </td></tr>
# <tr><td>train_LSTM_011e8_00025</td><td>0.037079139990966126</td></tr>
# <tr><td>train_LSTM_011e8_00026</td><td>0.03794416916255505 </td></tr>
# <tr><td>train_LSTM_011e8_00027</td><td>0.0384760267806155  </td></tr>
# <tr><td>train_LSTM_011e8_00028</td><td>0.03720407104981579 </td></tr>
# <tr><td>train_LSTM_011e8_00029</td><td>0.03151830958264443 </td></tr>
# <tr><td>train_LSTM_011e8_00030</td><td>0.03404996129606953 </td></tr>
# <tr><td>train_LSTM_011e8_00031</td><td>0.031222337720855243</td></tr>
# <tr><td>train_LSTM_011e8_00032</td><td>0.03392468079520971 </td></tr>
# <tr><td>train_LSTM_011e8_00033</td><td>0.034052296362998016</td></tr>
# <tr><td>train_LSTM_011e8_00034</td><td>0.03424787191732993 </td></tr>
# <tr><td>train_LSTM_011e8_00035</td><td>0.03206584511620377 </td></tr>
# <tr><td>train_LSTM_011e8_00036</td><td>0.0839761602465029  </td></tr>
# <tr><td>train_LSTM_011e8_00037</td><td>0.370214182843801   </td></tr>
# <tr><td>train_LSTM_011e8_00038</td><td>0.041065350544271226</td></tr>
# <tr><td>train_LSTM_011e8_00039</td><td>0.02793959486911076 </td></tr>
# <tr><td>train_LSTM_011e8_00040</td><td>0.04327640472543047 </td></tr>
# <tr><td>train_LSTM_011e8_00041</td><td>0.10339606325963825 </td></tr>
# <tr><td>train_LSTM_011e8_00042</td><td>0.14636775142661831 </td></tr>
# <tr><td>train_LSTM_011e8_00043</td><td>0.07993390890455566 </td></tr>
# <tr><td>train_LSTM_011e8_00044</td><td>0.1871034183230965  </td></tr>
# <tr><td>train_LSTM_011e8_00045</td><td>0.03455496557828032 </td></tr>
# <tr><td>train_LSTM_011e8_00046</td><td>0.03594455617327851 </td></tr>
# <tr><td>train_LSTM_011e8_00047</td><td>0.035164193077285674</td></tr>
# <tr><td>train_LSTM_011e8_00048</td><td>0.037405039276819464</td></tr>
# <tr><td>train_LSTM_011e8_00049</td><td>0.04481661166879915 </td></tr>
# <tr><td>train_LSTM_011e8_00050</td><td>0.03695781243285613 </td></tr>
# <tr><td>train_LSTM_011e8_00051</td><td>0.03914942903639    </td></tr>
# <tr><td>train_LSTM_011e8_00052</td><td>0.03713470773858414 </td></tr>
# <tr><td>train_LSTM_011e8_00053</td><td>0.03797746764287197 </td></tr>
# <tr><td>train_LSTM_011e8_00054</td><td>0.04012738639113023 </td></tr>
# <tr><td>train_LSTM_011e8_00055</td><td>0.037991424812930975</td></tr>
# <tr><td>train_LSTM_011e8_00056</td><td>0.04044714138585354 </td></tr>
# <tr><td>train_LSTM_011e8_00057</td><td>0.03876694537314296 </td></tr>
# <tr><td>train_LSTM_011e8_00058</td><td>0.03810719819741577 </td></tr>
# <tr><td>train_LSTM_011e8_00059</td><td>0.03444453894745239 </td></tr>
# <tr><td>train_LSTM_011e8_00060</td><td>0.03441698601544634 </td></tr>
# <tr><td>train_LSTM_011e8_00061</td><td>0.03752142125482261 </td></tr>
# <tr><td>train_LSTM_011e8_00062</td><td>0.0583980809873843  </td></tr>
# <tr><td>train_LSTM_011e8_00063</td><td>0.0328334962562248  </td></tr>
# <tr><td>train_LSTM_011e8_00064</td><td>0.04044060300589207 </td></tr>
# <tr><td>train_LSTM_011e8_00065</td><td>0.047014649311323424</td></tr>
# <tr><td>train_LSTM_011e8_00066</td><td>0.04178045225371544 </td></tr>
# <tr><td>train_LSTM_011e8_00067</td><td>0.03484409716726134 </td></tr>
# <tr><td>train_LSTM_011e8_00068</td><td>0.036012877384828966</td></tr>
# <tr><td>train_LSTM_011e8_00069</td><td>0.03826987951602459 </td></tr>
# <tr><td>train_LSTM_011e8_00070</td><td>0.030617265960904794</td></tr>
# <tr><td>train_LSTM_011e8_00071</td><td>0.037124132058123815</td></tr>
# <tr><td>train_LSTM_011e8_00072</td><td>0.027328739346176967</td></tr>
# <tr><td>train_LSTM_011e8_00073</td><td>0.033293135735794475</td></tr>
# <tr><td>train_LSTM_011e8_00074</td><td>0.027332744341978844</td></tr>
# <tr><td>train_LSTM_011e8_00075</td><td>0.03315948149434627 </td></tr>
# <tr><td>train_LSTM_011e8_00076</td><td>0.03442174654950519 </td></tr>
# <tr><td>train_LSTM_011e8_00077</td><td>0.028509507968370994</td></tr>
# <tr><td>train_LSTM_011e8_00078</td><td>0.22745760495133924 </td></tr>
# <tr><td>train_LSTM_011e8_00079</td><td>0.03422757098463022 </td></tr>
# <tr><td>train_LSTM_011e8_00080</td><td>0.02747011786853494 </td></tr>
# <tr><td>train_LSTM_011e8_00081</td><td>0.031363313469541805</td></tr>
# <tr><td>train_LSTM_011e8_00082</td><td>0.02895251185541999 </td></tr>
# <tr><td>train_LSTM_011e8_00083</td><td>0.07341466939402702 </td></tr>
# <tr><td>train_LSTM_011e8_00084</td><td>3.920585998020078   </td></tr>
# <tr><td>train_LSTM_011e8_00085</td><td>0.029436617604485887</td></tr>
# <tr><td>train_LSTM_011e8_00086</td><td>0.4400287503364586  </td></tr>
# <tr><td>train_LSTM_011e8_00087</td><td>0.42738648642015653 </td></tr>
# <tr><td>train_LSTM_011e8_00088</td><td>0.08033633471239304 </td></tr>
# <tr><td>train_LSTM_011e8_00089</td><td>0.04446445169102582 </td></tr>
# <tr><td>train_LSTM_011e8_00090</td><td>0.036294741827739854</td></tr>
# <tr><td>train_LSTM_011e8_00091</td><td>0.03744009524325148 </td></tr>
# <tr><td>train_LSTM_011e8_00092</td><td>0.03449670706393707 </td></tr>
# <tr><td>train_LSTM_011e8_00093</td><td>0.038367389936113105</td></tr>
# <tr><td>train_LSTM_011e8_00094</td><td>0.038959358063415155</td></tr>
# <tr><td>train_LSTM_011e8_00095</td><td>0.03979421392641887 </td></tr>
# <tr><td>train_LSTM_011e8_00096</td><td>0.03637016316223967 </td></tr>
# <tr><td>train_LSTM_011e8_00097</td><td>0.03939997360970565 </td></tr>
# <tr><td>train_LSTM_011e8_00098</td><td>0.03969379165857754 </td></tr>
# <tr><td>train_LSTM_011e8_00099</td><td>0.0361432273134413  </td></tr>
# <tr><td>train_LSTM_011e8_00100</td><td>0.035554006668090166</td></tr>
# <tr><td>train_LSTM_011e8_00101</td><td>0.039229557321709047</td></tr>
# <tr><td>train_LSTM_011e8_00102</td><td>0.0357651449824769  </td></tr>
# <tr><td>train_LSTM_011e8_00103</td><td>0.032077054167176454</td></tr>
# <tr><td>train_LSTM_011e8_00104</td><td>0.035255725184933286</td></tr>
# <tr><td>train_LSTM_011e8_00105</td><td>0.03568281280120273 </td></tr>
# <tr><td>train_LSTM_011e8_00106</td><td>0.04394642510595135 </td></tr>
# <tr><td>train_LSTM_011e8_00107</td><td>0.03618810263932427 </td></tr>
# <tr><td>train_LSTM_011e8_00108</td><td>0.051658228674191474</td></tr>
# <tr><td>train_LSTM_011e8_00109</td><td>0.039748189259337305</td></tr>
# <tr><td>train_LSTM_011e8_00110</td><td>0.04837794680639276 </td></tr>
# <tr><td>train_LSTM_011e8_00111</td><td>0.033871281100346595</td></tr>
# <
# 2024-01-18 22:49:17,964	ERROR tune_controller.py:1374 -- Trial task failed for trial train_LSTM_011e8_00627
# Traceback (most recent call last):
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/worker.py", line 2624, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ValueError): ray::ImplicitFunc.train() (pid=61923, ip=192.168.0.125, actor_id=03010d9158316929e3f5bcb601000000, repr=train_LSTM)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/trainable.py", line 342, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/_internal/util.py", line 88, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 115, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 332, in _trainable_func
#     output = fn()
#   File "/tmp/ipykernel_3690/415540101.py", line 68, in train_LSTM
#   File "/tmp/ipykernel_3690/415540101.py", line 34, in do_train
#   File "/tmp/ipykernel_3690/3031508849.py", line 19, in eval_dl_method
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 474, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 957, in check_array
#     _assert_all_finite(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 122, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 171, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
# 2024-01-18 22:49:37,794	ERROR tune_controller.py:1374 -- Trial task failed for trial train_LSTM_011e8_00629
# Traceback (most recent call last):
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/worker.py", line 2624, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ValueError): ray::ImplicitFunc.train() (pid=62063, ip=192.168.0.125, actor_id=b9aa4f025346b31164ec7f5501000000, repr=train_LSTM)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/trainable.py", line 342, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/_internal/util.py", line 88, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 115, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 332, in _trainable_func
#     output = fn()
#   File "/tmp/ipykernel_3690/415540101.py", line 68, in train_LSTM
#   File "/tmp/ipykernel_3690/415540101.py", line 34, in do_train
#   File "/tmp/ipykernel_3690/3031508849.py", line 19, in eval_dl_method
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 474, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 957, in check_array
#     _assert_all_finite(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 122, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 171, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
# 2024-01-18 23:12:49,406	ERROR tune_controller.py:1374 -- Trial task failed for trial train_LSTM_011e8_00672
# Traceback (most recent call last):
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/worker.py", line 2624, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ValueError): ray::ImplicitFunc.train() (pid=65244, ip=192.168.0.125, actor_id=e8679609f8b0c65f57b3ad0b01000000, repr=train_LSTM)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/trainable.py", line 342, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/_internal/util.py", line 88, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 115, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 332, in _trainable_func
#     output = fn()
#   File "/tmp/ipykernel_3690/415540101.py", line 68, in train_LSTM
#   File "/tmp/ipykernel_3690/415540101.py", line 34, in do_train
#   File "/tmp/ipykernel_3690/3031508849.py", line 19, in eval_dl_method
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 474, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 957, in check_array
#     _assert_all_finite(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 122, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 171, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
# 2024-01-18 23:12:53,357	ERROR tune_controller.py:1374 -- Trial task failed for trial train_LSTM_011e8_00674
# Traceback (most recent call last):
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/worker.py", line 2624, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ValueError): ray::ImplicitFunc.train() (pid=65400, ip=192.168.0.125, actor_id=041f510c83ba164391140bc601000000, repr=train_LSTM)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/trainable.py", line 342, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/_internal/util.py", line 88, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 115, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 332, in _trainable_func
#     output = fn()
#   File "/tmp/ipykernel_3690/415540101.py", line 68, in train_LSTM
#   File "/tmp/ipykernel_3690/415540101.py", line 34, in do_train
#   File "/tmp/ipykernel_3690/3031508849.py", line 19, in eval_dl_method
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 474, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 957, in check_array
#     _assert_all_finite(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 122, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 171, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
# 2024-01-18 23:30:15,248	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.506 s, which may be a performance bottleneck.
# 2024-01-18 23:30:15,248	WARNING util.py:202 -- The `process_trial_result` operation took 0.507 s, which may be a performance bottleneck.
# 2024-01-18 23:30:15,248	WARNING util.py:202 -- Processing trial results took 0.507 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-01-18 23:30:15,249	WARNING util.py:202 -- The `process_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-01-19 00:06:56,927	ERROR tune_controller.py:1374 -- Trial task failed for trial train_LSTM_011e8_00764
# Traceback (most recent call last):
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/worker.py", line 2624, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ValueError): ray::ImplicitFunc.train() (pid=72099, ip=192.168.0.125, actor_id=f46035f1061524f0b898f84501000000, repr=train_LSTM)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/trainable.py", line 342, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/_internal/util.py", line 88, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 115, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 332, in _trainable_func
#     output = fn()
#   File "/tmp/ipykernel_3690/415540101.py", line 68, in train_LSTM
#   File "/tmp/ipykernel_3690/415540101.py", line 34, in do_train
#   File "/tmp/ipykernel_3690/3031508849.py", line 19, in eval_dl_method
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 474, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 957, in check_array
#     _assert_all_finite(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 122, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 171, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
# 2024-01-19 00:30:36,207	ERROR tune_controller.py:1374 -- Trial task failed for trial train_LSTM_011e8_00807
# Traceback (most recent call last):
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/worker.py", line 2624, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ValueError): ray::ImplicitFunc.train() (pid=75239, ip=192.168.0.125, actor_id=9a3634b7e1d03a7c15a7bdc901000000, repr=train_LSTM)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/trainable.py", line 342, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/_internal/util.py", line 88, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 115, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 332, in _trainable_func
#     output = fn()
#   File "/tmp/ipykernel_3690/415540101.py", line 68, in train_LSTM
#   File "/tmp/ipykernel_3690/415540101.py", line 34, in do_train
#   File "/tmp/ipykernel_3690/3031508849.py", line 19, in eval_dl_method
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 474, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 957, in check_array
#     _assert_all_finite(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 122, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 171, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
# 2024-01-19 00:30:48,249	ERROR tune_controller.py:1374 -- Trial task failed for trial train_LSTM_011e8_00809
# Traceback (most recent call last):
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/worker.py", line 2624, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ValueError): ray::ImplicitFunc.train() (pid=75379, ip=192.168.0.125, actor_id=95cc48e848025541630848d001000000, repr=train_LSTM)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/trainable.py", line 342, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/_internal/util.py", line 88, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 115, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 332, in _trainable_func
#     output = fn()
#   File "/tmp/ipykernel_3690/415540101.py", line 68, in train_LSTM
#   File "/tmp/ipykernel_3690/415540101.py", line 34, in do_train
#   File "/tmp/ipykernel_3690/3031508849.py", line 19, in eval_dl_method
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 474, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 957, in check_array
#     _assert_all_finite(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 122, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 171, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
# 2024-01-19 01:20:15,591	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.518 s, which may be a performance bottleneck.
# 2024-01-19 01:20:15,591	WARNING util.py:202 -- The `process_trial_result` operation took 0.519 s, which may be a performance bottleneck.
# 2024-01-19 01:20:15,591	WARNING util.py:202 -- Processing trial results took 0.519 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-01-19 01:20:15,592	WARNING util.py:202 -- The `process_trial_result` operation took 0.519 s, which may be a performance bottleneck.
# 2024-01-19 01:21:57,879	ERROR tune_controller.py:1374 -- Trial task failed for trial train_LSTM_011e8_00899
# Traceback (most recent call last):
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/worker.py", line 2624, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ValueError): ray::ImplicitFunc.train() (pid=81933, ip=192.168.0.125, actor_id=b48581c6c8bc09226dfa73c501000000, repr=train_LSTM)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/trainable.py", line 342, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/_internal/util.py", line 88, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 115, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 332, in _trainable_func
#     output = fn()
#   File "/tmp/ipykernel_3690/415540101.py", line 68, in train_LSTM
#   File "/tmp/ipykernel_3690/415540101.py", line 34, in do_train
#   File "/tmp/ipykernel_3690/3031508849.py", line 19, in eval_dl_method
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 474, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 957, in check_array
#     _assert_all_finite(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 122, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 171, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
# 2024-01-19 01:46:13,150	ERROR tune_controller.py:1374 -- Trial task failed for trial train_LSTM_011e8_00942
# Traceback (most recent call last):
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/worker.py", line 2624, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ValueError): ray::ImplicitFunc.train() (pid=85088, ip=192.168.0.125, actor_id=1b5f591aa7cb31e26ee768bc01000000, repr=train_LSTM)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/trainable.py", line 342, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/_internal/util.py", line 88, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 115, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 332, in _trainable_func
#     output = fn()
#   File "/tmp/ipykernel_3690/415540101.py", line 68, in train_LSTM
#   File "/tmp/ipykernel_3690/415540101.py", line 34, in do_train
#   File "/tmp/ipykernel_3690/3031508849.py", line 19, in eval_dl_method
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 474, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 957, in check_array
#     _assert_all_finite(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 122, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 171, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
# 2024-01-19 01:46:17,194	ERROR tune_controller.py:1374 -- Trial task failed for trial train_LSTM_011e8_00944
# Traceback (most recent call last):
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/worker.py", line 2624, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ValueError): ray::ImplicitFunc.train() (pid=85211, ip=192.168.0.125, actor_id=a6dae6eba845bc8ee0d37e3c01000000, repr=train_LSTM)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/trainable.py", line 342, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/_internal/util.py", line 88, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 115, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 332, in _trainable_func
#     output = fn()
#   File "/tmp/ipykernel_3690/415540101.py", line 68, in train_LSTM
#   File "/tmp/ipykernel_3690/415540101.py", line 34, in do_train
#   File "/tmp/ipykernel_3690/3031508849.py", line 19, in eval_dl_method
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 474, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 957, in check_array
#     _assert_all_finite(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 122, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 171, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
# 2024-01-19 02:38:37,823	ERROR tune_controller.py:1374 -- Trial task failed for trial train_LSTM_011e8_01032
# Traceback (most recent call last):
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/_private/worker.py", line 2624, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ValueError): ray::ImplicitFunc.train() (pid=91667, ip=192.168.0.125, actor_id=47b513a1cd32e5639ad786d701000000, repr=train_LSTM)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/trainable.py", line 342, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/air/_internal/util.py", line 88, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 115, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/ray/tune/trainable/function_trainable.py", line 332, in _trainable_func
#     output = fn()
#   File "/tmp/ipykernel_3690/415540101.py", line 68, in train_LSTM
#   File "/tmp/ipykernel_3690/415540101.py", line 34, in do_train
#   File "/tmp/ipykernel_3690/3031508849.py", line 19, in eval_dl_method
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 474, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 957, in check_array
#     _assert_all_finite(
# ...
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 474, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/metrics/_regression.py", line 101, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 957, in check_array
#     _assert_all_finite(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 122, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "/home/skchen/venv/ml4t/lib/python3.8/site-packages/sklearn/utils/validation.py", line 171, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
# 2024-01-19 14:40:17,727	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.613 s, which may be a performance bottleneck.
# 2024-01-19 14:40:17,728	WARNING util.py:202 -- The `process_trial_result` operation took 0.614 s, which may be a performance bottleneck.
# 2024-01-19 14:40:17,728	WARNING util.py:202 -- Processing trial results took 0.614 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-01-19 14:40:17,729	WARNING util.py:202 -- The `process_trial_result` operation took 0.614 s, which may be a performance bottleneck.
# 2024-01-19 14:50:18,340	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 1.204 s, which may be a performance bottleneck.
# 2024-01-19 14:50:18,340	WARNING util.py:202 -- The `process_trial_result` operation took 1.204 s, which may be a performance bottleneck.
# 2024-01-19 14:50:18,340	WARNING util.py:202 -- Processing trial results took 1.205 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-01-19 14:50:18,341	WARNING util.py:202 -- The `process_trial_result` operation took 1.205 s, which may be a performance bottleneck.
# 2024-01-19 15:14:53,170	WARNING tune.py:186 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2024-01-19 15:14:53,987	ERROR tune.py:1038 -- Trials did not complete: [train_LSTM_011e8_00627, train_LSTM_011e8_00629, train_LSTM_011e8_00672, train_LSTM_011e8_00674, train_LSTM_011e8_00764, train_LSTM_011e8_00807, train_LSTM_011e8_00809, train_LSTM_011e8_00899, train_LSTM_011e8_00942, train_LSTM_011e8_00944, train_LSTM_011e8_01032, train_LSTM_011e8_01077, train_LSTM_011e8_01079, train_LSTM_011e8_01707, train_LSTM_011e8_01709, train_LSTM_011e8_01739, train_LSTM_011e8_01752, train_LSTM_011e8_01754, train_LSTM_011e8_01844, train_LSTM_011e8_01887, train_LSTM_011e8_01889, train_LSTM_011e8_01977, train_LSTM_011e8_01979, train_LSTM_011e8_02022, train_LSTM_011e8_02024, train_LSTM_011e8_02112, train_LSTM_011e8_02114, train_LSTM_011e8_02157, train_LSTM_011e8_02159]
# 2024-01-19 15:14:53,987	INFO tune.py:1042 -- Total run time: 80981.32 seconds (80980.49 seconds for the tuning loop).
# 2024-01-19 15:14:53,988	WARNING tune.py:1057 -- Experiment has been interrupted, but the most recent state was saved.
# Resume experiment with: tune.run(..., resume=True)
# 2024-01-19 15:15:01,331	WARNING experiment_analysis.py:193 -- Failed to fetch metrics for 35 trial(s):
# - train_LSTM_011e8_02325: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02325: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02325_2325_activation_type=1,hidden_size=8,lr=0.1000,momentum=0.6936,num_fc_layers=1,num_layers=2,optim_type=1,re_2024-01-19_14-52-11')
# - train_LSTM_011e8_02326: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02326: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02326_2326_activation_type=2,hidden_size=8,lr=0.1000,momentum=0.8016,num_fc_layers=1,num_layers=2,optim_type=1,re_2024-01-19_14-52-25')
# - train_LSTM_011e8_02327: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02327: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02327_2327_activation_type=3,hidden_size=8,lr=0.1000,momentum=0.1280,num_fc_layers=1,num_layers=2,optim_type=1,re_2024-01-19_14-52-36')
# - train_LSTM_011e8_02328: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02328: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02328_2328_activation_type=1,hidden_size=16,lr=0.1000,momentum=0.1962,num_fc_layers=1,num_layers=2,optim_type=1,r_2024-01-19_14-55-38')
# - train_LSTM_011e8_02329: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02329: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02329_2329_activation_type=2,hidden_size=16,lr=0.1000,momentum=0.7471,num_fc_layers=1,num_layers=2,optim_type=1,r_2024-01-19_14-55-54')
# - train_LSTM_011e8_02330: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02330: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02330_2330_activation_type=3,hidden_size=16,lr=0.1000,momentum=0.7936,num_fc_layers=1,num_layers=2,optim_type=1,r_2024-01-19_14-56-26')
# - train_LSTM_011e8_02331: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02331: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02331_2331_activation_type=1,hidden_size=32,lr=0.1000,momentum=0.4848,num_fc_layers=1,num_layers=2,optim_type=1,r_2024-01-19_14-56-35')
# - train_LSTM_011e8_02332: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02332: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02332_2332_activation_type=2,hidden_size=32,lr=0.1000,momentum=0.8771,num_fc_layers=1,num_layers=2,optim_type=1,r_2024-01-19_14-56-35')
# - train_LSTM_011e8_02333: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02333: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02333_2333_activation_type=3,hidden_size=32,lr=0.1000,momentum=0.1261,num_fc_layers=1,num_layers=2,optim_type=1,r_2024-01-19_14-57-04')
# - train_LSTM_011e8_02334: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02334: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02334_2334_activation_type=1,hidden_size=64,lr=0.1000,momentum=0.5169,num_fc_layers=1,num_layers=2,optim_type=1,r_2024-01-19_14-57-17')
# - train_LSTM_011e8_02335: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02335: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02335_2335_activation_type=2,hidden_size=64,lr=0.1000,momentum=0.3115,num_fc_layers=1,num_layers=2,optim_type=1,r_2024-01-19_14-57-27')
# - train_LSTM_011e8_02336: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02336: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02336_2336_activation_type=3,hidden_size=64,lr=0.1000,momentum=0.6830,num_fc_layers=1,num_layers=2,optim_type=1,r_2024-01-19_15-00-34')
# - train_LSTM_011e8_02337: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02337: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02337_2337_activation_type=1,hidden_size=128,lr=0.1000,momentum=0.2188,num_fc_layers=1,num_layers=2,optim_type=1,_2024-01-19_15-00-50')
# - train_LSTM_011e8_02338: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02338: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02338_2338_activation_type=2,hidden_size=128,lr=0.1000,momentum=0.2381,num_fc_layers=1,num_layers=2,optim_type=1,_2024-01-19_15-01-22')
# - train_LSTM_011e8_02339: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02339: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02339_2339_activation_type=3,hidden_size=128,lr=0.1000,momentum=0.5341,num_fc_layers=1,num_layers=2,optim_type=1,_2024-01-19_15-01-29')
# - train_LSTM_011e8_02340: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02340: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02340_2340_activation_type=1,hidden_size=8,lr=0.0010,momentum=0.8670,num_fc_layers=2,num_layers=2,optim_type=1,re_2024-01-19_15-01-31')
# - train_LSTM_011e8_02341: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02341: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02341_2341_activation_type=2,hidden_size=8,lr=0.0010,momentum=0.7014,num_fc_layers=2,num_layers=2,optim_type=1,re_2024-01-19_15-02-01')
# - train_LSTM_011e8_02342: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02342: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02342_2342_activation_type=3,hidden_size=8,lr=0.0010,momentum=0.8097,num_fc_layers=2,num_layers=2,optim_type=1,re_2024-01-19_15-02-15')
# - train_LSTM_011e8_02343: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02343: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02343_2343_activation_type=1,hidden_size=16,lr=0.0010,momentum=0.2752,num_fc_layers=2,num_layers=2,optim_type=1,r_2024-01-19_15-02-20')
# - train_LSTM_011e8_02344: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02344: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02344_2344_activation_type=2,hidden_size=16,lr=0.0010,momentum=0.2310,num_fc_layers=2,num_layers=2,optim_type=1,r_2024-01-19_15-05-29')
# - train_LSTM_011e8_02345: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02345: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02345_2345_activation_type=3,hidden_size=16,lr=0.0010,momentum=0.7592,num_fc_layers=2,num_layers=2,optim_type=1,r_2024-01-19_15-05-45')
# - train_LSTM_011e8_02346: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02346: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02346_2346_activation_type=1,hidden_size=32,lr=0.0010,momentum=0.8660,num_fc_layers=2,num_layers=2,optim_type=1,r_2024-01-19_15-06-15')
# - train_LSTM_011e8_02347: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02347: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02347_2347_activation_type=2,hidden_size=32,lr=0.0010,momentum=0.3354,num_fc_layers=2,num_layers=2,optim_type=1,r_2024-01-19_15-06-18')
# - train_LSTM_011e8_02348: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02348: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02348_2348_activation_type=3,hidden_size=32,lr=0.0010,momentum=0.6334,num_fc_layers=2,num_layers=2,optim_type=1,r_2024-01-19_15-06-24')
# - train_LSTM_011e8_02349: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02349: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02349_2349_activation_type=1,hidden_size=64,lr=0.0010,momentum=0.7941,num_fc_layers=2,num_layers=2,optim_type=1,r_2024-01-19_15-06-57')
# - train_LSTM_011e8_02350: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02350: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02350_2350_activation_type=2,hidden_size=64,lr=0.0010,momentum=0.5337,num_fc_layers=2,num_layers=2,optim_type=1,r_2024-01-19_15-07-02')
# - train_LSTM_011e8_02351: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02351: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02351_2351_activation_type=3,hidden_size=64,lr=0.0010,momentum=0.3582,num_fc_layers=2,num_layers=2,optim_type=1,r_2024-01-19_15-07-18')
# - train_LSTM_011e8_02352: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02352: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02352_2352_activation_type=1,hidden_size=128,lr=0.0010,momentum=0.3341,num_fc_layers=2,num_layers=2,optim_type=1,_2024-01-19_15-10-16')
# - train_LSTM_011e8_02353: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02353: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02353_2353_activation_type=2,hidden_size=128,lr=0.0010,momentum=0.3231,num_fc_layers=2,num_layers=2,optim_type=1,_2024-01-19_15-10-38')
# - train_LSTM_011e8_02354: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02354: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02354_2354_activation_type=3,hidden_size=128,lr=0.0010,momentum=0.3325,num_fc_layers=2,num_layers=2,optim_type=1,_2024-01-19_15-11-02')
# - train_LSTM_011e8_02355: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02355: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02355_2355_activation_type=1,hidden_size=8,lr=0.0100,momentum=0.8653,num_fc_layers=2,num_layers=2,optim_type=1,re_2024-01-19_15-11-09')
# - train_LSTM_011e8_02356: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02356: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02356_2356_activation_type=2,hidden_size=8,lr=0.0100,momentum=0.4781,num_fc_layers=2,num_layers=2,optim_type=1,re_2024-01-19_15-11-11')
# - train_LSTM_011e8_02357: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02357: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02357_2357_activation_type=3,hidden_size=8,lr=0.0100,momentum=0.2573,num_fc_layers=2,num_layers=2,optim_type=1,re_2024-01-19_15-11-41')
# - train_LSTM_011e8_02358: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02358: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02358_2358_activation_type=1,hidden_size=16,lr=0.0100,momentum=0.8818,num_fc_layers=2,num_layers=2,optim_type=1,r_2024-01-19_15-11-48')
# - train_LSTM_011e8_02359: FileNotFoundError('Could not fetch metrics for train_LSTM_011e8_02359: both result.json and progress.csv were not found at /home/skchen/ray_results/train_LSTM_2024-01-18_16-45-12/train_LSTM_011e8_02359_2359_activation_type=2,hidden_size=16,lr=0.0100,momentum=0.7812,num_fc_layers=2,num_layers=2,optim_type=1,r_2024-01-19_15-12-04')

# %%
mse_list = []
trial_list = list(analysis.trial_dataframes.values())
for i, trial in enumerate(trial_list):
    if trial.empty == False:
        d = pd.DataFrame.from_dict({"mse_score": trial.describe().loc['mean', 'mse_score'], "trial_id": trial.loc[0:0,'trial_id'] })
    else:
        d = pd.DataFrame.from_dict({"mse_score": [np.NaN], "trial_id": [np.NaN]})
    mse_list.append(d)
mse_df = pd.concat(mse_list)
mse_df = mse_df.reset_index().loc[:, ["mse_score", "trial_id"]]
print(mse_df)
# Out:
#       mse_score     trial_id
# 0      0.033607  011e8_00000
# 1      0.033156  011e8_00001
# 2      0.032631  011e8_00002
# 3      0.035605  011e8_00003
# 4      0.033798  011e8_00004
# ...         ...          ...
# 2355        NaN          NaN
# 2356        NaN          NaN
# 2357        NaN          NaN
# 2358        NaN          NaN
# 2359        NaN          NaN
#
# [2360 rows x 2 columns]

# %%
config_df = pd.DataFrame(analysis.get_all_configs().values())
print(config_df)

results = pd.concat([mse_df, config_df], axis=1)
print(results)

sorted_results = results.sort_values(by="mse_score")
print(sorted_results.head(100))
sorted_results.to_csv("sorted_results.csv")

best_config = config_df.iloc[sorted_results.index[0]]
print(best_config)
# Out:
#       return_period  seq_len     lr  momentum  optim_type  num_layers  hidden_size  num_fc_layers  activation_type
# 0                 2        2  0.001  0.220866           1           1            8              1                1
# 1                 2        2  0.001  0.765792           1           1            8              1                2
# 2                 2        2  0.001  0.491901           1           1            8              1                3
# 3                 2        2  0.001  0.551665           1           1           16              1                1
# 4                 2        2  0.001  0.855840           1           1           16              1                2
# ...             ...      ...    ...       ...         ...         ...          ...            ...              ...
# 2355              5        2  0.010  0.865340           1           2            8              2                1
# 2356              5        2  0.010  0.478112           1           2            8              2                2
# 2357              5        2  0.010  0.257278           1           2            8              2                3
# 2358              5        2  0.010  0.881755           1           2           16              2                1
# 2359              5        2  0.010  0.781229           1           2           16              2                2
#
# [2360 rows x 9 columns]
#       mse_score     trial_id  return_period  seq_len     lr  momentum  optim_type  num_layers  hidden_size  num_fc_layers  activation_type
# 0      0.033607  011e8_00000              2        2  0.001  0.220866           1           1            8              1                1
# 1      0.033156  011e8_00001              2        2  0.001  0.765792           1           1            8              1                2
# 2      0.032631  011e8_00002              2        2  0.001  0.491901           1           1            8              1                3
# 3      0.035605  011e8_00003              2        2  0.001  0.551665           1           1           16              1                1
# 4      0.033798  011e8_00004              2        2  0.001  0.855840           1           1           16              1                2
# ...         ...          ...            ...      ...    ...       ...         ...         ...          ...            ...              ...
# 2355        NaN          NaN              5        2  0.010  0.865340           1           2            8              2                1
# 2356        NaN          NaN              5        2  0.010  0.478112           1           2            8              2                2
# 2357        NaN          NaN              5        2  0.010  0.257278           1           2            8              2                3
# 2358        NaN          NaN              5        2  0.010  0.881755           1           2           16              2                1
# 2359        NaN          NaN              5        2  0.010  0.781229           1           2           16              2                2
#
# [2360 rows x 11 columns]
#       mse_score     trial_id  return_period  seq_len     lr  momentum  optim_type  num_layers  hidden_size  num_fc_layers  activation_type
# 782    0.026811  011e8_00782              2        2  0.010  0.203482           2           2            8              3                3
# 833    0.027088  011e8_00833              2        2  0.010  0.434828           2           4           32              1                3
# 835    0.027196  011e8_00835              2        2  0.010  0.879192           2           4           64              1                2
# 798    0.027219  011e8_00798              2        2  0.100  0.549838           2           2           16              3                1
# 797    0.027224  011e8_00797              2        2  0.100  0.258337           2           2            8              3                3
# ...         ...          ...            ...      ...    ...       ...         ...         ...          ...            ...              ...
# 570    0.027336  011e8_00570              2        2  0.100  0.591930           2           1            8              1                1
# 1046   0.027337  011e8_01046              2        2  0.001  0.514437           2           8           64              3                3
# 781    0.027338  011e8_00781              2        2  0.010  0.630218           2           2            8              3                2
# 995    0.027338  011e8_00995              2        2  0.001  0.869041           2           8           16              2                3
# 960    0.027340  011e8_00960              2        2  0.010  0.259593           2           8            8              1                1
#
# [100 rows x 11 columns]
# return_period      2.000000
# seq_len            2.000000
# lr                 0.010000
# momentum           0.203482
# optim_type         2.000000
# num_layers         2.000000
# hidden_size        8.000000
# num_fc_layers      3.000000
# activation_type    3.000000
# Name: 782, dtype: float64

# %%
id_str_of_best = f"{int(best_config.return_period)}_{int(best_config.seq_len)}_{best_config.lr}_{best_config.momentum}_{int(best_config.optim_type)}_{int(best_config.num_layers)}_{int(best_config.hidden_size)}_{int(best_config.num_fc_layers)}_{int(best_config.activation_type)}"
best_model_name = f"{log_dir}/{id_str_of_best}.pt"
print(best_model_name)
# Out:
# 2_2_0.01_0.20348197806978982_2_2_8_3_3
# /mnt/AIWorkSpace/work/fin-ml/runs/MSFT/2024-01-18_16.45.12/2_2_0.01_0.20348197806978982_2_2_8_3_3.pt

# %%
sorted_results = pd.read_csv("sorted_results.csv", dtype='str')
best_config = sorted_results.loc[0]

id_str_of_best = f"{best_config.return_period}_{best_config.seq_len}_{best_config.lr}_{best_config.momentum}_{best_config.optim_type}_{best_config.num_layers}_{best_config.hidden_size}_{best_config.num_fc_layers}_{best_config.activation_type}"
best_model_name = f"{log_dir}/2024-01-18_16.45.12/{id_str_of_best}.pt"
print(best_model_name)
# Out:
# Unnamed: 0                          782
# mse_score          0.026810780139407762
# trial_id                    011e8_00782
# return_period                         2
# seq_len                               2
# lr                                 0.01
# momentum            0.20348197806978982
# optim_type                            2
# num_layers                            2
# hidden_size                           8
# num_fc_layers                         3
# activation_type                       3
# Name: 0, dtype: object
# /mnt/AIWorkSpace/work/fin-ml/runs/MSFT/2024-01-18_16.45.12/2_2_0.01_0.20348197806978982_2_2_8_3_3.pt

# %%
import math 
from sklearn.metrics import mean_squared_error

pd.set_option('display.precision', 5)

return_period = int(best_config.return_period)
seq_len = int(best_config.seq_len)
train_loader, test_loader, features = prepare_dataloader(return_period, seq_len)

model = StockPricePredictionLSTM(seq_len, input_size=len(features),
                                     hidden_size=int(best_config.hidden_size),num_layers=int(best_config.num_layers),
                                     num_fc_layers=int(best_config.num_fc_layers), activation_type=int(best_config.activation_type))

model.load_state_dict(torch.load(best_model_name))
model.to(device)
model.eval()

(trainScore, train_y_gt, train_y_pred, _)= eval_dl_method(model, train_loader, device=device)
(testScore, test_y_gt, test_y_pred, _)  = eval_dl_method(model, test_loader, device=device)
# print(test_y_gt)
print(f"Train RMSE: {trainScore:.2f}\nTest RMSE: {testScore:.2f}")
# Out:
# Train RMSE: 0.02
# Test RMSE: 0.03

# %%
target_raw = stk_data.loc[test_loader.dataset.X.index.values].xs(_TARGET_STK, axis=1, level=1)
# print(target_raw)
target_raw = target_raw.drop(target_raw.index[range(seq_len - 1)], axis=0)

test_y_pred_df = pd.DataFrame(index=target_raw.index.copy())
test_y_pred_df['pred_price'] = test_y_pred
test_y_pred_df['pred_price'] = (test_y_pred_df['pred_price'] + 1) * target_raw['Close']
test_y_pred_df = test_y_pred_df.shift(return_period)
tmp_data = pd.concat([target_raw, test_y_pred_df], axis=1).dropna()

tmp_data['Close'].plot()
tmp_data['pred_price'].plot()
pyplot.legend()
pyplot.show()
